# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/nktun/Downloads/Log VDT 2023 - Jun 9 23.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548567 entries, 0 to 548566
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CUSTOMER_ID              548567 non-null  int64
#  1   Wallet_Name              548563 non-null  object
#  2   FULL_NAME                548563 non-null  object
#  3   DOB                      506516 non-null  object
#  4   NATIONALITY              430451 non-null  object
#  5   CUSTOMER_MOBILE          547611 non-null  float64
#  6   NATIONAL_ID              386698 non-null  object
#  7   Nguoi_dai_dien_hop_phap  0 non-null       float64
#  8   Bank_Acc_Num             0 non-null       float64
#  9   Card_type                0 non-null       float64
#  10  Bank_account             114859 non-null  object
#  11  BANK_NAME                114859 non-null  object
#  12  Begin_Balance            531916 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['CUSTOMER_ID', 'Wallet_Name', 'FULL_NAME', 'DOB', 'NATIONALITY',
#        'CUSTOMER_MOBILE', 'NATIONAL_ID', 'Nguoi_dai_dien_hop_phap',
#        'Bank_Acc_Num', 'Card_type', 'Bank_account', 'BANK_NAME',
#        'Begin_Balance', 'Fundin', 'Receive', 'P2P', 'Billpay', 'Fundout',
#        'Transfer', 'Ending_Balance', 'Dinh_danh_CCCD', 'Lien_ket_ngan_hang',
#        'Kich_hoat_vi'],
#       dtype='object')

# %%
Balance_columns = ['Begin_Balance', 'Fundin', 'Receive', 'P2P', 'Billpay', 'Fundout',
       'Transfer']

# %%
# Fill Null = 0
df[Balance_columns] = df[Balance_columns].fillna(0)
df.head(10)
# Out:
#    CUSTOMER_ID      Wallet_Name        FULL_NAME         DOB NATIONALITY
# 0           28       Hoàng Hiền       Hoàng Hiền  1988-11-20    Việt Nam  \
# 1           62     Võ Duy Khang     Võ Duy Khang  1992-01-07    Việt Nam
# 2          168            Lê Vy            Lê Vy  1997-01-05    Việt Nam
# 3          198   Phạm Quang Nam   Phạm Quang Nam  1993-04-28    Việt Nam
# 4          212  BUI BICH PHUONG  BUI BICH PHUONG  1993-10-03    Việt Nam
# 5          375        Hieu  Chu        Hieu  Chu         NaN    Việt Nam
# 6          423                                           NaN    Việt Nam
# 7          446            si do            si do         NaN    Việt Nam
# 8          848        Nguyễn Vi        Nguyễn Vi         NaN    Việt Nam
# 9          883                                           NaN    Việt Nam
#
#    CUSTOMER_MOBILE   NATIONAL_ID  Nguoi_dai_dien_hop_phap  Bank_Acc_Num
# 0      982155089.0     131466743                      NaN           NaN  \
# ...

# %%
# # Remove commas and white spaces from the entire DataFrame
df = df.replace(',', '', regex=True)

# %%
# Check for double quotation marks
column_to_check = df.columns
# cells_with_quotes = df[df[column_to_check].str.contains('"', na=False)]
cells_with_quotes = df.applymap(lambda x: ',' in str(x))

# %%
print(cells_with_quotes.sum()) #Checking for cells with double quotation marks
# Out:
# CUSTOMER_ID                0
# Wallet_Name                0
# FULL_NAME                  0
# DOB                        0
# NATIONALITY                0
# CUSTOMER_MOBILE            0
# NATIONAL_ID                0
# Nguoi_dai_dien_hop_phap    0
# Bank_Acc_Num               0
# Card_type                  0
# Bank_account               0
# BANK_NAME                  0
# Begin_Balance              0
# Fundin                     0
# Receive                    0
# P2P                        0
# Billpay                    0
# Fundout                    0
# Transfer                   0
# Ending_Balance             0
# Dinh_danh_CCCD             0
# Lien_ket_ngan_hang         0
# Kich_hoat_vi               0
# dtype: int64

# %%
df.to_csv('C:/Users/nktun/Downloads/2023 Log VDT - Fill 0.csv', index=False)
